# %% [markdown]
# ### __Generative Models and GANs__
# ![title](https://miro.medium.com/max/1250/1*vBmmy3bnFF4wfruuCwhiGA.png)

# %% [markdown]
# Simply they are a class of Unsupervised Machine Learning Models which are used to generate some Data . It uses the Joint Probability Distribution over the observations

# %% [markdown]
# ##### Generative Adversarial Networks belong to the set of generative models. It means that they are able to produce / to generate (we’ll see how) new content
# - Naturally, this ability to generate new content makes GANs look a little bit “magic”, at least at first sight

# %% [markdown]
# __Generative model Vs Discriminative model__
# The discriminative models learn the conditional probability distribution $P(y \mid x)$ i.e. the decision boundary between classes e.g. logistic regression, neural network. The generative models learn the joint probability distribution $P(x, y)$  i.e. the distribution of individual classes e.g. naive Bayes, Gaussian discriminant analysis (GDA).
# ![title](https://kharshit.github.io/img/discriminative_generative.png)

# %% [markdown]
# GANs were invented by Ian Goodfellow et al. in 2014 in Generative Adversarial Nets. __It has two networks, competing with each other:__
#
# __Generator try to fool the discriminator by generating real-looking images
# Discriminator try to distinguish real images from the fake ones generated by the Generator__

# %% [markdown]
# ![title](https://miro.medium.com/max/875/1*XKanAdkjQbg1eDDMF2-4ow.png)

# %% [markdown]
# ![title](https://kharshit.github.io/img/gan.png)

# %% [markdown]
# #### Training
# __Training involves alternating between training the discriminator and the generator.__ The real loss and fake loss are used to calculate the discriminator losses as follows.
# ![title](https://kharshit.github.io/img/gan_MNIST.png)

# %% [markdown]
# GANs take a long time to train. On a single GPU a GAN might take hours, and on a single CPU more than a day. While difficult to tune and therefore to use, GANs have stimulated a lot of interesting research and writing.

# %% [markdown]
# __BatchNorm__:
# <br>
# - Construct different mini-batches for real and fake, i.e. each mini-batch needs to contain only all real images or all generated images.
# - when batchnorm is not an option use instance normalization (for each sample, subtract mean and divide by standard deviation).

# %% [markdown]
# ![title](https://github.com/soumith/ganhacks/raw/master/images/batchmix.png)

# %% [markdown]
# __The two networks can be considered black boxes representing some arbitrarily complicated function that is applied to either noise or real data__. The input to the generator is some random noise, which produces a fake image, and the input to the discriminator is both fake samples as well as samples from our real data set. The discriminator then makes a binary decision about whether the image supplied, z, is a real image D(z)=1, or a fake image, D(z)=0.
# ![title](https://miro.medium.com/max/875/1*3sl6xiqg_5vV2e-3jUsm0A.png)

# %% [markdown]
# In summary, the game follows with:
#
# - The generator trying to maximize the probability of making the discriminator mistakes its inputs as real.
# - And the discriminator guiding the generator to produce more realistic images.
